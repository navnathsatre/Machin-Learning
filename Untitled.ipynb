# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
filename = "D:\\jupyter notebook workspace\\MLR\\Toyota_a.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=2,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=1437,
    max_cols_analyzed=39,
)
# Out:
# File encoding decoder utf-8 does not work for this file
# File encoding decoder iso-8859-11 does not work for this file
# File encoding decoder cpl252 does not work for this file
# Shape of your Data Set: (1436, 38)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 1436 rows, 38 cols
# Too many columns to print
#     Numeric Columns: ['HP']
#     Integer-Categorical Columns: ['Price', 'Age_08_04', 'Mfg_Month', 'KM', 'cc', 'Doors', 'Gears', 'Quarterly_Tax', 'Weight', 'Guarantee_Period']
#     String-Categorical Columns: ['Fuel_Type', 'Color']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
import pandas as pd
df = pd.read_csv("D:\\jupyter notebook workspace\\EDA\\archive\\heart.csv")
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...
