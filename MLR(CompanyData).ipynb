# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
data=pd.read_csv("D:\\DATA SCIENCE\\DATA SCIENCE ASSIGNMENTS\\Assignments\\Decision Tree\\Company_Data.csv")
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
df=data.copy()

# %%
df['ShelveLoc'].replace({'Bad':0,'Medium':1,'Good':2},inplace=True)
df['Urban'].replace({'No':0,'Yes':1},inplace=True)
df['US'].replace({'No':0,'Yes':1},inplace=True)

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          2   65
# 2    10.06        113      35           10         269     80          1   59
# 3     7.40        117     100            4         466     97          1   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          2   33
# 396   6.14        139      23            3          37    120          1   55
# 397   7.41        162      26           12         368    159          1   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          2   49
#
#      Education  Urban  US
# ...

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# ShelveLoc    0.554458   0.038549 -0.053465     0.056552   -0.020614  0.050924
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Urban       -0.015419   0.066594  0.037967     0.042035   -0.052025  0.047016
# US           0.177093   0.016869  0.089601     0.684460    0.060564  0.057861
#
# ...

# %%
model=smf.ols('Sales~CompPrice+Income+Advertising+Population+Price+ShelveLoc+Age+Education+Urban+US',data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     252.9
# Date:                Sat, 27 Feb 2021   Prob (F-statistic):          2.15e-163
# Time:                        19:48:59   Log-Likelihood:                -579.33
# No. Observations:                 400   AIC:                             1181.
# Df Residuals:                     389   BIC:                             1225.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.4028      0.616      8.775      0.000       4.192       6.613
# ...

# %%
model1=smf.ols('Sales~CompPrice+Income+Advertising+Price+ShelveLoc+Age',data=df).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     420.7
# Date:                Sat, 27 Feb 2021   Prob (F-statistic):          1.26e-167
# Time:                        19:50:12   Log-Likelihood:                -581.44
# No. Observations:                 400   AIC:                             1177.
# Df Residuals:                     393   BIC:                             1205.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.2624      0.515     10.215      0.000       4.250       6.275
# ...
